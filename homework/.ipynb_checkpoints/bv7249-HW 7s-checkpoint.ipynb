# %% [markdown]
# This jupyter notebook only contains the answers to homework 7s. The code program for homework 7 can be found in the Jupyter Notebook titled "bv7249-HW7
#
# Stability Analysis:
#     Yes we are able to do a stability analysis on -2ycos(x). Our lamda in this is simply -2cos(x). Our variable x is related to lamda as when cos(x) is positive, the value of lambda is negtive, which promotes stability. On the other hand, the value of lamda is positive when the value of cos(x) is negative, which will cause it to be unstable and can result in more errors. To find the stability condition, we have to understand that the solution is decaying when hcos(x) is between 0 and 1. Therefore we need h to be between 0 and 1 in order for this condition to be true for all values of x.
