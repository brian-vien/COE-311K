# %%
import math
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 50)
plt.subplot(2, 2,1) #(row, column, active area) number of active areas indicates number of different graphs
plt.plot(x, np.sin(x), 'r')
plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x), 'g')
plt.show()

# %%
y = np.sin(x)
plt.scatter(x,y)
plt.show()

# %%
x = np.random.rand(1000)
y = np.random.rand(1000)
size = np.random.rand(1000) * 50
color = np.random.rand(1000)
plt.scatter(x, y, size, color)
plt.colorbar()
plt.show()

# %%
plt.hist(x, 50)
plt.show()

# %%
x = np.linspace(0, 2 * np.pi, 50)
plt.plot(x, np.sin(x), 'r-x', label='Sin(x)')
plt.plot(x, np.cos(x), 'g-^', label='Cos(x)')
plt.legend() # Display the legend.
plt.xlabel('Rads') # Add a label to the x-axis.
plt.ylabel('Amplitude') # Add a label to the y-axis.
plt.title('Sin and Cos Waves') # Add a graph title.
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D #use this for a mesh

z1 = np.empty([2001,2001import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D #use this for a mesh])
im = plt.imshow(z1, cmap='hot')
fig = plt.colorbar(im, orientation='horizontal')
plt.show(fig)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D #use this for a mesh

z1 = np.empty([2001,2001])
im = plt.imshow(z1, cmap='hot')
fig = plt.colorbar(im, orientation='horizontal')
plt.show(fig)

# %%
i = 0
j = 0
t = 1
z = np.empty([2001,2001])
for x in np.arange(-10,10,.01):
    i = i + 1
    j = 0
    for y in np.arange(-10,10,.01):
        j = j + 1
        z[i][j] = x*x + y*y

# %%
z
# Out:
# array([[7.81250185e-03, 7.81250185e-03, 7.81250185e-03, ...,
#         7.81250185e-03, 7.81250185e-03, 7.81250185e-03],
#        [7.81250185e-03, 2.00000000e+02, 1.99800100e+02, ...,
#         1.99400900e+02, 1.99600400e+02, 1.99800100e+02],
#        [7.81250185e-03, 1.99800100e+02, 1.99600200e+02, ...,
#         1.99201000e+02, 1.99400500e+02, 1.99600200e+02],
#        ...,
#        [9.00000000e-01, 1.99400900e+02, 1.99201000e+02, ...,
#         1.98801800e+02, 1.99001300e+02, 1.99201000e+02],
#        [9.00000000e-01, 1.99600400e+02, 1.99400500e+02, ...,
#         1.99001300e+02, 1.99200800e+02, 1.99400500e+02],
#        [9.00000000e-01, 1.99800100e+02, 1.99600200e+02, ...,
#         1.99201000e+02, 1.99400500e+02, 1.99600200e+02]])

# %%
def f1(x,y):
    return (x*x+y*y)
x = np.linspace(-10, 10, 2000)
y = np.linspace(-10, 10, 2000)
X, Y = np.meshgrid(x, y)
Z = f1(X, Y)

# %%
Z
# Out:
# array([[200.        , 199.80000005, 199.6002003 , ..., 199.6002003 ,
#         199.80000005, 200.        ],
#        [199.80000005, 199.6000001 , 199.40020035, ..., 199.40020035,
#         199.6000001 , 199.80000005],
#        [199.6002003 , 199.40020035, 199.2004006 , ..., 199.2004006 ,
#         199.40020035, 199.6002003 ],
#        ...,
#        [199.6002003 , 199.40020035, 199.2004006 , ..., 199.2004006 ,
#         199.40020035, 199.6002003 ],
#        [199.80000005, 199.6000001 , 199.40020035, ..., 199.40020035,
#         199.6000001 , 199.80000005],
#        [200.        , 199.80000005, 199.6002003 , ..., 199.6002003 ,
#         199.80000005, 200.        ]])

# %%
fig1 = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='hot')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
ax.view_init(45, 0)
